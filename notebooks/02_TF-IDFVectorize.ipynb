# %% [markdown]
# ## Convert Dataset to Vec TF-IDF

# %%
import pandas as pd
import os
import json
from datetime import datetime as dt
from multiprocessing import Pool

from sklearn.utils import shuffle
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

import tensorflow as tf 
from tensorflow.python.lib.io import file_io
import _pickle as pickle

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/home/jovyan/work/google_key.json'

# %%
basepath = 'gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/'

# %%
with file_io.FileIO('{}dataset.csv'.format(basepath), 'r') as f:
    dataset_df = pd.read_csv(f)
dataset_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  cat1  cat2  cat3  cat4  \
# 0           0             0    58  2293  7861     1
# 1           1             1    71  3014     2     1
# 2           2             2    36  2783     5     1
# 3           3             3    27  3688    16     1
# 4           4             4    46  3725    12    10
#
#                                                 name
# 0                                  garf sobrem turim
# 1             enfeit mes natalin cas led orb christm
# 2                           livr malet ades profisso
# 3                  bol pes medic medicin ball liveup
# 4  gel limp fac microesfoliaca jon isotonic fac s...

# %% [markdown]
# ## Normalize dataframe name

# %%
dataset_df['name'] = dataset_df['name'].fillna(' ')

# %% [markdown]
# ## Shuffle dataset

# %%
dataset_df = shuffle(dataset_df)

# %% [markdown]
# ## Split Dataset in training and test

# %%
X_train_raw, X_test_raw, y_train_raw, y_test_raw = train_test_split(dataset_df.name, dataset_df.cat1, test_size=0.1, random_state=1001)

# %% [markdown]
# ## Vectorize

# %% [markdown]
# ### Dimenstion Reduction

# %%
x_to_reduction = TfidfVectorizer().fit_transform(X_train_raw)

# %%
svd = TruncatedSVD(n_components=50000, random_state=1001)
svd.fit(x_to_reduction)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-18-6712fbf81a62> in <module>
#       1 svd = TruncatedSVD(n_components=10000, random_state=1001)
# ----> 2 svd.fit(x_to_reduction)
#
# /opt/conda/lib/python3.6/site-packages/sklearn/decomposition/truncated_svd.py in fit(self, X, y)
#     140             Returns the transformer object.
#     141         """
# --> 142         self.fit_transform(X)
#     143         return self
#     144
#
# /opt/conda/lib/python3.6/site-packages/sklearn/decomposition/truncated_svd.py in fit_transform(self, X, y)
#     176             U, Sigma, VT = randomized_svd(X, self.n_components,
#     177                                           n_iter=self.n_iter,
# --> 178                                           random_state=random_state)
#     179         else:
#     180             raise ValueError("unknown algorithm %r" % self.algorithm)
#
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/extmath.py in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state)
#     324
#     325     Q = randomized_range_finder(M, n_random, n_iter,
# --> 326                                 power_iteration_normalizer, random_state)
#     327
#     328     # project M to the (k + p) dimensional space using the basis vectors
#
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/extmath.py in randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     214             Q = safe_sparse_dot(A.T, Q)
#     215         elif power_iteration_normalizer == 'LU':
# --> 216             Q, _ = linalg.lu(safe_sparse_dot(A, Q), permute_l=True)
#     217             Q, _ = linalg.lu(safe_sparse_dot(A.T, Q), permute_l=True)
#     218         elif power_iteration_normalizer == 'QR':
#
# /opt/conda/lib/python3.6/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     133     """
#     134     if issparse(a) or issparse(b):
# --> 135         ret = a * b
#     136         if dense_output and hasattr(ret, "toarray"):
#     137             ret = ret.toarray()
#
# /opt/conda/lib/python3.6/site-packages/scipy/sparse/base.py in __mul__(self, other)
#     468                 return self._mul_vector(other.ravel()).reshape(M, 1)
#     469             elif other.ndim == 2 and other.shape[0] == N:
# --> 470                 return self._mul_multivector(other)
#     471
#     472         if isscalarlike(other):
#
# /opt/conda/lib/python3.6/site-packages/scipy/sparse/compressed.py in _mul_multivector(self, other)
#     467
#     468         result = np.zeros((M,n_vecs), dtype=upcast_char(self.dtype.char,
# --> 469                                                         other.dtype.char))
#     470
#     471         # csr_matvecs or csc_matvecs
#
# MemoryError:

# %% [markdown]
# ## Vectorize

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(X_train_raw)
X_train = vectorizer.transform(X_train_raw)
X_test  = vectorizer.transform(X_test_raw)

with file_io.FileIO('{}tfidf/vectorizer.pk'.format(basepath), 'w+') as f:
    pickle.dump(vectorizer, f)

# %% [markdown]
# ## LabelBinarizer

# %%
laberizer = LabelBinarizer()
laberizer.fit(dataset_df.cat1)
y_train = laberizer.transform(y_train_raw)
y_test  = laberizer.transform(y_test_raw)

with file_io.FileIO('{}tfidf/laberizer.pk'.format(basepath), 'w+') as f:
    pickle.dump(laberizer, f)

# %% [markdown]
# ## Persist Trainingset

# %%
def _int64_feature(value):
    return tf.train.Feature(int64_list=tf.train.Int64List(value=value))

def create_record(data):
    features = tf.train.Features(feature={
        'label': tf.train.Feature(int64_list=tf.train.Int64List(value=data[1])),
        'features': tf.train.Feature(float_list=tf.train.FloatList(value=data[0].toarray()[0]))
    })
    
    return tf.train.Example(features=features)

# %%
index = 1
chunck_size = 5000
for i in range(0, len(y_train), chunck_size):
    start = dt.now()
    filename = "{}tfidf/trainset/{}.tfrecord".format(basepath, str(index).zfill(5))
    writer = tf.python_io.TFRecordWriter(filename)
    
    with Pool(10) as pool:
        for example in pool.map(create_record, zip(X_train[i:i+chunck_size], y_train[i:i+chunck_size])):
            writer.write(example.SerializeToString())
    
    writer.close()
    print("diff %ds: %s" % ((dt.now() - start).total_seconds(), filename))
    index += 1
# Out:
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00001.tfrecord
# diff 116s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00002.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00003.tfrecord
# diff 139s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00004.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00005.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00006.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00007.tfrecord
# diff 118s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00008.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00009.tfrecord
# diff 118s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00010.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00011.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00012.tfrecord
# diff 126s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00013.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00014.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00015.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00016.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00017.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00018.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00019.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00020.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00021.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00022.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00023.tfrecord
# diff 118s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00024.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00025.tfrecord
# diff 122s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00026.tfrecord
# diff 140s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00027.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00028.tfrecord
# diff 117s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00029.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00030.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00031.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00032.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00033.tfrecord
# diff 126s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00034.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00035.tfrecord
# diff 118s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00036.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00037.tfrecord
# diff 138s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00038.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00039.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00040.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00041.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00042.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00043.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00044.tfrecord
# diff 122s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00045.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00046.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00047.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00048.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00049.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00050.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00051.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00052.tfrecord
# diff 126s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00053.tfrecord
# diff 115s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00054.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00055.tfrecord
# diff 116s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00056.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00057.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00058.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00059.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00060.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00061.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00062.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00063.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00064.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00065.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00066.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00067.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00068.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00069.tfrecord
# diff 142s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00070.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00071.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00072.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00073.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00074.tfrecord
# diff 122s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00075.tfrecord
# diff 118s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00076.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00077.tfrecord
# diff 122s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00078.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00079.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00080.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00081.tfrecord
# diff 151s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00082.tfrecord
# diff 117s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00083.tfrecord
# diff 136s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00084.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00085.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00086.tfrecord
# diff 126s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00087.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00088.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00089.tfrecord
# diff 146s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00090.tfrecord
# diff 138s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00091.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00092.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00093.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00094.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00095.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00096.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00097.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00098.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00099.tfrecord
# diff 126s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00100.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00101.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00102.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00103.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00104.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00105.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00106.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00107.tfrecord
# diff 143s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00108.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00109.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00110.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00111.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00112.tfrecord
# diff 138s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00113.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00114.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00115.tfrecord
# diff 137s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00116.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00117.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00118.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00119.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00120.tfrecord
# diff 142s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00121.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00122.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00123.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00124.tfrecord
# diff 140s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00125.tfrecord
# diff 142s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00126.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00127.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00128.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00129.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00130.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00131.tfrecord
# diff 144s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00132.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00133.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00134.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00135.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00136.tfrecord
# diff 140s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00137.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00138.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00139.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00140.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00141.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00142.tfrecord
# diff 139s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00143.tfrecord
# diff 146s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00144.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00145.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00146.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00147.tfrecord
# diff 148s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00148.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00149.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00150.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00151.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00152.tfrecord
# diff 116s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00153.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00154.tfrecord
# diff 136s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00155.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00156.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00157.tfrecord
# diff 122s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00158.tfrecord
# diff 142s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00159.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00160.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00161.tfrecord
# diff 136s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00162.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00163.tfrecord
# diff 142s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00164.tfrecord
# diff 147s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00165.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00166.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00167.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00168.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00169.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00170.tfrecord
# diff 138s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00171.tfrecord
# diff 141s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00172.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00173.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00174.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00175.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00176.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00177.tfrecord
# diff 136s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00178.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00179.tfrecord
# diff 126s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00180.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00181.tfrecord
# diff 118s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00182.tfrecord
# diff 138s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00183.tfrecord
# diff 140s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00184.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00185.tfrecord
# diff 141s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00186.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00187.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00188.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00189.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00190.tfrecord
# diff 142s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00191.tfrecord
# diff 143s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00192.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00193.tfrecord
# diff 142s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00194.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00195.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00196.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00197.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00198.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00199.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00200.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00201.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00202.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00203.tfrecord
# diff 126s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00204.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00205.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00206.tfrecord
# diff 126s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00207.tfrecord
# diff 145s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00208.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00209.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00210.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00211.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00212.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00213.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00214.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00215.tfrecord
# diff 122s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00216.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00217.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00218.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00219.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00220.tfrecord
# diff 138s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00221.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00222.tfrecord
# diff 126s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00223.tfrecord
# diff 122s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00224.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00225.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00226.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00227.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00228.tfrecord
# diff 138s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00229.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00230.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00231.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00232.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00233.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00234.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00235.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00236.tfrecord
# diff 140s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00237.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00238.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00239.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00240.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00241.tfrecord
# diff 149s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00242.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00243.tfrecord
# diff 137s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00244.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00245.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00246.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00247.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00248.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00249.tfrecord
# diff 149s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00250.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00251.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00252.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00253.tfrecord
# diff 141s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00254.tfrecord
# diff 126s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00255.tfrecord
# diff 143s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00256.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00257.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00258.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00259.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00260.tfrecord
# diff 142s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00261.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00262.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00263.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00264.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00265.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00266.tfrecord
# diff 119s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00267.tfrecord
# diff 129s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00268.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00269.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00270.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00271.tfrecord
# diff 122s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00272.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00273.tfrecord
# diff 138s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00274.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00275.tfrecord
# diff 122s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00276.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00277.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00278.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00279.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00280.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00281.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00282.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00283.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00284.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00285.tfrecord
# diff 136s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00286.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00287.tfrecord
# diff 118s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00288.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00289.tfrecord
# diff 137s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00290.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00291.tfrecord
# diff 139s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00292.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00293.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00294.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00295.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00296.tfrecord
# diff 124s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00297.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00298.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00299.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00300.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00301.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00302.tfrecord
# diff 120s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00303.tfrecord
# diff 141s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00304.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00305.tfrecord
# diff 139s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00306.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00307.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00308.tfrecord
# diff 117s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00309.tfrecord
# diff 157s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00310.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00311.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00312.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00313.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00314.tfrecord
# diff 134s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00315.tfrecord
# diff 122s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00316.tfrecord
# diff 136s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00317.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00318.tfrecord
# diff 136s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00319.tfrecord
# diff 127s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00320.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00321.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00322.tfrecord
# diff 131s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00323.tfrecord
# diff 123s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00324.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00325.tfrecord
# diff 133s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00326.tfrecord
# diff 128s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00327.tfrecord
# diff 125s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00328.tfrecord
# diff 135s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00329.tfrecord
# diff 132s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00330.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00331.tfrecord
# diff 130s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00332.tfrecord
# diff 121s: gs://bitservices-bigdata/skyhub/minos/dataset/20182208-202242/tfidf/trainset/00333.tfrecord

# %% [markdown]
# ## Persist Testset

# %%
index = 1
chunck_size = 10000
for i in range(0, len(y_train), chunck_size):
    start = dt.now()
    filename = "{}tfidf/testset/{}.tfrecord".format(basepath, str(index).zfill(5))
    writer = tf.python_io.TFRecordWriter(filename)
    
    with Pool(10) as pool:
        for example in pool.map(create_record, zip(X_test[i:i+chunck_size], y_test[i:i+chunck_size])):
            writer.write(example.SerializeToString())
    
    writer.close()
    print("diff %ds: %s" % ((dt.now() - start).total_seconds(), filename))
    index += 1

# %%
y_test

# %% [markdown]
# ## Persit Metadata

# %%
metadata = {
    'train_samples_count': len(y_train),
    'test_samples_count': len(y_test),
    'features_count': len(vectorizer.get_feature_names()),
    'features_names': vectorizer.get_feature_names(),
    'lavels_count': len(laberizer.classes_),
    'labels_names': laberizer.classes_.tolist()
}

with file_io.FileIO('{}tfidf/metadata.json'.format(basepath), 'w+') as f:
    f.write(json.dumps(metadata))

# %%
metadata
